# %% [markdown]
# <a href="https://colab.research.google.com/github/Neloxe/nlp-project/blob/main/RNN-Glove-4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, confusion_matrix

# %%
# 1. CHARGEMENT DES DONNÉES
data = pd.read_csv('./train.csv', sep=',')
texts = data['comment_text'].astype(str).values
label_names = ['toxic', 'obscene', 'insult', 'identity_hate']
labels = data[label_names].values

# %%
# 2. TOKENISATION ET VECTORISATION
max_words = 20000  # Vocabulaire max
max_len = 100  # Longueur max des séquences
embedding_dim = 100  # Taille des embeddings

tokenizer = Tokenizer(num_words=max_words, oov_token="<OOV>")
tokenizer.fit_on_texts(texts)
word_index = tokenizer.word_index

sequences = tokenizer.texts_to_sequences(texts)
padded_sequences = pad_sequences(sequences, maxlen=max_len, padding='post')

# %%
# 3. CHARGEMENT DES EMBEDDINGS PRÉ-ENTRAÎNÉS (ex: GloVe)

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

embeddings_index = {}
with open('/content/drive/MyDrive/glove.6B.100d.txt', encoding="utf-8") as f:
    for line in f:
        values = line.split()
        word = values[0]
        vectors = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = vectors

# Création de la matrice d'embedding
embedding_matrix = np.zeros((len(word_index) + 1, embedding_dim))
for word, i in word_index.items():
    if i < max_words:
        vector = embeddings_index.get(word)
        if vector is not None:
            embedding_matrix[i] = vector
# Out:
# Mounted at /content/drive

# %%
# 4. SPLIT DES DONNÉES
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, labels, test_size=0.2, random_state=42)

# 5. CONSTRUCTION DU MODÈLE
model = Sequential([
    Embedding(len(word_index) + 1, embedding_dim, weights=[embedding_matrix], input_length=max_len, trainable=False),
    Bidirectional(LSTM(128, return_sequences=True)),
    Dropout(0.5),
    Bidirectional(LSTM(64)),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(4, activation='sigmoid')  # 6 classes multi-label (toxic, severe_toxic, obscene, etc.)
])

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)              │ ?                           │      22,134,300 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_4 (Bidirectional)      │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_5 (Bidirectional)      │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 22,134,300 (84.44 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 22,134,300 (84.44 MB)

# %%
# 6. ENTRAÎNEMENT DU MODÈLE
history = model.fit(X_train, y_train, epochs=50, batch_size=64, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 50s 25ms/step - accuracy: 0.9123 - loss: 0.0154 - val_accuracy: 0.9905 - val_loss: 0.1728
# Epoch 2/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 82s 25ms/step - accuracy: 0.9348 - loss: 0.0147 - val_accuracy: 0.9849 - val_loss: 0.1714
# Epoch 3/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 49s 25ms/step - accuracy: 0.9327 - loss: 0.0141 - val_accuracy: 0.9855 - val_loss: 0.1639
# Epoch 4/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 83s 25ms/step - accuracy: 0.9295 - loss: 0.0137 - val_accuracy: 0.9862 - val_loss: 0.1726
# Epoch 5/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 50s 25ms/step - accuracy: 0.9306 - loss: 0.0140 - val_accuracy: 0.9857 - val_loss: 0.1846
# Epoch 6/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 83s 25ms/step - accuracy: 0.8982 - loss: 0.0132 - val_accuracy: 0.9880 - val_loss: 0.1896
# Epoch 7/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 80s 25ms/step - accuracy: 0.8783 - loss: 0.0126 - val_accuracy: 0.9721 - val_loss: 0.1729
# Epoch 8/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 83s 25ms/step - accuracy: 0.8416 - loss: 0.0124 - val_accuracy: 0.9813 - val_loss: 0.1865
# Epoch 9/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 50s 25ms/step - accuracy: 0.8808 - loss: 0.0121 - val_accuracy: 0.9861 - val_loss: 0.1757
# Epoch 10/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 82s 25ms/step - accuracy: 0.8832 - loss: 0.0121 - val_accuracy: 0.9829 - val_loss: 0.1795
# Epoch 11/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 82s 25ms/step - accuracy: 0.8750 - loss: 0.0114 - val_accuracy: 0.9802 - val_loss: 0.1823
# Epoch 12/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 82s 25ms/step - accuracy: 0.8587 - loss: 0.0115 - val_accuracy: 0.9839 - val_loss: 0.1921
# Epoch 13/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 81s 25ms/step - accuracy: 0.8834 - loss: 0.0109 - val_accuracy: 0.9750 - val_loss: 0.1924
# Epoch 14/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 82s 25ms/step - accuracy: 0.8726 - loss: 0.0109 - val_accuracy: 0.9849 - val_loss: 0.2033
# Epoch 15/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 50s 25ms/step - accuracy: 0.8620 - loss: 0.0107 - val_accuracy: 0.9815 - val_loss: 0.1883
# Epoch 16/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 49s 25ms/step - accuracy: 0.8843 - loss: 0.0104 - val_accuracy: 0.9784 - val_loss: 0.2026
# Epoch 17/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 82s 25ms/step - accuracy: 0.8910 - loss: 0.0098 - val_accuracy: 0.9806 - val_loss: 0.1860
# Epoch 18/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 50s 25ms/step - accuracy: 0.9028 - loss: 0.0103 - val_accuracy: 0.9861 - val_loss: 0.1893
# Epoch 19/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 82s 25ms/step - accuracy: 0.9144 - loss: 0.0098 - val_accuracy: 0.9719 - val_loss: 0.1938
# Epoch 20/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 81s 25ms/step - accuracy: 0.8741 - loss: 0.0095 - val_accuracy: 0.9806 - val_loss: 0.2121
# Epoch 21/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 50s 25ms/step - accuracy: 0.8929 - loss: 0.0102 - val_accuracy: 0.9859 - val_loss: 0.2025
# Epoch 22/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 82s 25ms/step - accuracy: 0.9002 - loss: 0.0095 - val_accuracy: 0.9741 - val_loss: 0.1942
# Epoch 23/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 82s 25ms/step - accuracy: 0.8701 - loss: 0.0093 - val_accuracy: 0.9757 - val_loss: 0.2037
# Epoch 24/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 82s 25ms/step - accuracy: 0.8486 - loss: 0.0096 - val_accuracy: 0.9719 - val_loss: 0.1946
# Epoch 25/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 82s 25ms/step - accuracy: 0.8899 - loss: 0.0090 - val_accuracy: 0.9721 - val_loss: 0.2067
# Epoch 26/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 82s 26ms/step - accuracy: 0.8801 - loss: 0.0089 - val_accuracy: 0.9827 - val_loss: 0.2072
# Epoch 27/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 81s 25ms/step - accuracy: 0.9165 - loss: 0.0089 - val_accuracy: 0.9831 - val_loss: 0.2084
# Epoch 28/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 82s 25ms/step - accuracy: 0.8961 - loss: 0.0085 - val_accuracy: 0.9829 - val_loss: 0.2165
# Epoch 29/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 81s 25ms/step - accuracy: 0.9100 - loss: 0.0080 - val_accuracy: 0.9797 - val_loss: 0.2092
# Epoch 30/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 82s 25ms/step - accuracy: 0.8996 - loss: 0.0088 - val_accuracy: 0.9759 - val_loss: 0.1954
# Epoch 31/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 83s 25ms/step - accuracy: 0.9233 - loss: 0.0090 - val_accuracy: 0.9840 - val_loss: 0.2080
# Epoch 32/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 81s 25ms/step - accuracy: 0.9149 - loss: 0.0082 - val_accuracy: 0.9845 - val_loss: 0.2201
# Epoch 33/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 50s 25ms/step - accuracy: 0.8928 - loss: 0.0087 - val_accuracy: 0.9749 - val_loss: 0.2057
# Epoch 34/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 82s 25ms/step - accuracy: 0.8954 - loss: 0.0084 - val_accuracy: 0.9834 - val_loss: 0.2078
# Epoch 35/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 82s 25ms/step - accuracy: 0.8822 - loss: 0.0083 - val_accuracy: 0.9841 - val_loss: 0.2158
# Epoch 36/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 82s 25ms/step - accuracy: 0.9033 - loss: 0.0082 - val_accuracy: 0.9811 - val_loss: 0.2214
# Epoch 37/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 82s 25ms/step - accuracy: 0.8751 - loss: 0.0087 - val_accuracy: 0.9767 - val_loss: 0.2308
# Epoch 38/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 50s 25ms/step - accuracy: 0.8705 - loss: 0.0083 - val_accuracy: 0.9753 - val_loss: 0.2171
# Epoch 39/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 49s 25ms/step - accuracy: 0.8645 - loss: 0.0081 - val_accuracy: 0.9742 - val_loss: 0.2213
# Epoch 40/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 83s 25ms/step - accuracy: 0.8835 - loss: 0.0080 - val_accuracy: 0.9806 - val_loss: 0.2213
# Epoch 41/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 50s 25ms/step - accuracy: 0.8968 - loss: 0.0081 - val_accuracy: 0.9782 - val_loss: 0.2230
# Epoch 42/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 82s 25ms/step - accuracy: 0.8939 - loss: 0.0079 - val_accuracy: 0.9823 - val_loss: 0.2471
# Epoch 43/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 50s 25ms/step - accuracy: 0.8992 - loss: 0.0075 - val_accuracy: 0.9819 - val_loss: 0.2344
# Epoch 44/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 83s 25ms/step - accuracy: 0.9253 - loss: 0.0075 - val_accuracy: 0.9853 - val_loss: 0.2294
# Epoch 45/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 50s 25ms/step - accuracy: 0.9275 - loss: 0.0071 - val_accuracy: 0.9855 - val_loss: 0.2175
# Epoch 46/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 82s 25ms/step - accuracy: 0.9379 - loss: 0.0075 - val_accuracy: 0.9817 - val_loss: 0.2282
# Epoch 47/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 82s 25ms/step - accuracy: 0.9327 - loss: 0.0078 - val_accuracy: 0.9817 - val_loss: 0.2208
# Epoch 48/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 81s 25ms/step - accuracy: 0.9255 - loss: 0.0072 - val_accuracy: 0.9720 - val_loss: 0.2110
# Epoch 49/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 50s 25ms/step - accuracy: 0.8836 - loss: 0.0070 - val_accuracy: 0.9778 - val_loss: 0.2210
# Epoch 50/50
# 1995/1995 ━━━━━━━━━━━━━━━━━━━━ 50s 25ms/step - accuracy: 0.8465 - loss: 0.0070 - val_accuracy: 0.9818 - val_loss: 0.2243

# %%
# Plot loss and accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# 7. PRÉDICTIONS ET ÉVALUATION
y_pred_proba = model.predict(X_test)
y_pred = (y_pred_proba > 0.5).astype(int)
# Out:
# 998/998 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step

# %%
# F1-Score par classe
f1_scores = f1_score(y_test, y_pred, average=None)
for i, label in enumerate(label_names):
    print(f"F1-Score for {label}: {f1_scores[i]:.4f}")

# Score F1 global (moyenne macro)
f1_macro = f1_score(y_test, y_pred, average='macro')
print(f"\nF1-Score Macro (moyenne des classes): {f1_macro:.4f}")

# 8. MATRICES DE CONFUSION
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
axes = axes.flatten()

for i, label in enumerate(label_names):
    cm = confusion_matrix(y_test[:, i], y_pred[:, i])
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Non", "Oui"], yticklabels=["Non", "Oui"], ax=axes[i])
    axes[i].set_title(f"Matrice de confusion - {label}")
    axes[i].set_xlabel("Prédit")
    axes[i].set_ylabel("Réel")

plt.tight_layout()
plt.show()
# Out:
# F1-Score for toxic: 0.7657
# F1-Score for obscene: 0.7727
# F1-Score for insult: 0.6858
# F1-Score for identity_hate: 0.4305
#
# F1-Score Macro (moyenne des classes): 0.6637
